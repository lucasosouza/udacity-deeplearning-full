# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /home/paperspace/anaconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
int_words[:10]
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155]

# %%
## Your code here
from collections import Counter
import random

def subsampling(int_words, threshold):
    words_count = Counter(int_words)
    total_count = len(int_words)
    p_drop = {}
    for word, count in words_count.items():
        frequency = count/total_count
        p_drop[word] = 1 - np.sqrt(threshold/frequency)
    
    return [word for word in int_words if np.random.random() < (1-p_drop[word])]
    
train_words = subsampling(int_words, 1e-5)# The final subsampled word list

# %%
len(int_words), len(train_words)
# Out:
# (16680599, 4625571)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = max(0, idx - R)
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding),-1,1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/paperspace/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-15-a0117d212314>:14: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6376 0.0270 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6200 0.0231 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5185 0.0232 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6000 0.0233 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4970 0.0228 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5389 0.0228 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5425 0.0230 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5528 0.0230 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5050 0.0229 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4040 0.0228 sec/batch
# Nearest to these: margarita, sync, evaluated, coughlin, travel, ribeira, beckmann, guimar,
# Nearest to time: sambia, hilton, omnipotence, jp, palmas, macbook, sectors, automobile,
# Nearest to other: inhibiting, coelacanth, ethers, jomini, doings, dulles, z, abounds,
# Nearest to was: astray, cook, explicated, egeria, germ, invokes, provers, commuter,
# Nearest to american: zal, nintoku, academies, seeded, dina, capitulation, saying, publicizing,
# Nearest to into: ape, holocene, worshipped, valentinianism, setae, evo, ezra, lal,
# Nearest to are: mulholland, destroying, prevenient, freshness, crystallographic, capita, much, fiesole,
# Nearest to have: unpleasantly, sigh, anson, brandauer, tenet, objectively, nbc, amortized,
# Nearest to experience: distinctions, defiant, wellesley, french, cottle, humphrey, upstairs, auger,
# Nearest to pressure: caudillo, monnet, dewitt, jackpots, breakdown, strongpoints, jutes, tenures,
# Nearest to pre: wanted, outlasted, defying, eristic, invisibly, knockout, pd, attracts,
# Nearest to mainly: gnu, preserve, japonica, rejection, hunsr, moldovan, kuti, it,
# Nearest to police: fruitarians, nasrani, charted, longinus, sondheim, amorite, trapezoidal, diminishes,
# Nearest to mathematics: arcturus, huygens, sepoy, interphase, buccaneers, sanders, spanning, outnumbered,
# Nearest to bbc: kala, quarrels, spinoff, couch, zionists, lycos, janis, luthier,
# Nearest to discovered: teaspoon, stubborn, walt, stoll, reunite, hammerstein, conforming, ponta,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4621 0.0242 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3727 0.0230 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3012 0.0228 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2330 0.0229 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1900 0.0230 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1739 0.0230 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0965 0.0228 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0425 0.0230 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0099 0.0228 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9731 0.0235 sec/batch
# Nearest to these: physical, because, sync, margarita, travel, suited, closely, problem,
# Nearest to time: sambia, hilton, sectors, omnipotence, strengthen, automobile, jp, revised,
# Nearest to other: inhibiting, coelacanth, interests, z, ethers, jomini, lacking, animal,
# Nearest to was: people, astray, cook, protection, evolve, instance, rainbow, commuter,
# Nearest to american: saying, seeded, academies, discovers, zal, outbursts, resorts, gda,
# Nearest to into: table, ape, holocene, worshipped, partly, preserve, evo, with,
# Nearest to are: mulholland, much, capita, destroying, master, crystallographic, equality, fleets,
# Nearest to have: objectively, nbc, anson, unpleasantly, sigh, tenet, performed, diaeresis,
# Nearest to experience: distinctions, wellesley, subsequently, french, syllable, defiant, upstairs, humphrey,
# Nearest to pressure: caudillo, dewitt, focusing, confirmed, breakdown, surrogate, nobility, substantiated,
# Nearest to pre: wanted, design, speakers, outlasted, while, species, always, offer,
# Nearest to mainly: gnu, preserve, rejection, injured, kepler, japonica, lucifer, moldovan,
# Nearest to police: longinus, rl, charted, maslow, fruitarians, totoro, deira, dion,
# Nearest to mathematics: outnumbered, huygens, arcturus, sepoy, title, away, forget, sanders,
# Nearest to bbc: kala, quarrels, spinoff, entire, couch, zionists, articles, janis,
# Nearest to discovered: hydrochloric, walt, negotiations, canyon, stoll, stubborn, righteousness, greats,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8852 0.0238 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8804 0.0228 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8741 0.0229 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8689 0.0230 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7922 0.0228 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7891 0.0231 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8032 0.0231 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7812 0.0229 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7865 0.0227 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7809 0.0227 sec/batch
# Nearest to these: physical, travel, because, margarita, sync, suited, evaluated, closely,
# Nearest to time: sambia, hilton, automobile, omnipotence, sectors, strengthen, jp, intertwined,
# Nearest to other: inhibiting, coelacanth, animal, doings, interests, z, ethers, ronald,
# Nearest to was: evolve, astray, cook, germ, people, collaborators, somehow, deserts,
# Nearest to american: academies, discovers, seeded, saying, gda, capitulation, zal, resorts,
# Nearest to into: holocene, ape, table, preserve, setae, valentinianism, partly, worshipped,
# Nearest to are: mulholland, destroying, capita, contradiction, freshness, axiom, much, placement,
# Nearest to have: anson, unpleasantly, nbc, objectively, sigh, tenet, inputs, pervasive,
# Nearest to experience: distinctions, wellesley, syllable, upstairs, restrict, subsequently, defiant, comments,
# Nearest to pressure: caudillo, dewitt, breakdown, focusing, surrogate, confirmed, nobility, inaccurately,
# Nearest to pre: wanted, design, defying, knockout, attracts, outlasted, stringent, speakers,
# Nearest to mainly: preserve, rejection, gnu, kepler, injured, container, lucifer, fimbulwinter,
# Nearest to police: longinus, rl, charted, invoke, dion, maslow, fruitarians, katrina,
# Nearest to mathematics: huygens, outnumbered, arcturus, sepoy, sanders, title, forget, fate,
# Nearest to bbc: kala, quarrels, spinoff, zionists, articles, couch, entire, speaks,
# Nearest to discovered: negotiations, walt, hydrochloric, canyon, stoll, greats, stubborn, destroying,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7648 0.0236 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7502 0.0228 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7252 0.0229 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6955 0.0229 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7328 0.0230 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7153 0.0230 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7060 0.0229 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7222 0.0227 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7103 0.0227 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6703 0.0226 sec/batch
# Nearest to these: physical, because, evaluated, travel, margarita, sync, closely, suited,
# Nearest to time: sambia, hilton, automobile, strengthen, omnipotence, jp, intertwined, advertisement,
# Nearest to other: inhibiting, doings, coelacanth, animal, ronald, ethers, dulles, codec,
# Nearest to was: collaborators, evolve, people, fall, germ, astray, cook, pbk,
# Nearest to american: poet, william, chemist, musician, physicist, discovers, actor, seeded,
# Nearest to into: holocene, ape, worshipped, table, valentinianism, setae, preserve, ezra,
# Nearest to are: freshness, mulholland, contradiction, destroying, axiom, capita, conscripted, prevenient,
# Nearest to have: anson, unpleasantly, objectively, sigh, ladefoged, nbc, lobbyist, pervasive,
# Nearest to experience: distinctions, wellesley, restrict, upstairs, syllable, defiant, auger, chi,
# Nearest to pressure: caudillo, dewitt, breakdown, surrogate, focusing, inaccurately, tenures, jackpots,
# Nearest to pre: wanted, outlasted, eristic, stringent, design, attracts, knockout, pd,
# Nearest to mainly: preserve, rejection, gnu, kepler, lucifer, container, fimbulwinter, predicting,
# Nearest to police: longinus, rl, invoke, charted, dion, leadership, fruitarians, totoro,
# Nearest to mathematics: huygens, outnumbered, arcturus, sepoy, sanders, title, kmt, cole,
# Nearest to bbc: spinoff, quarrels, kala, couch, janis, aerosol, slavery, lycos,
# Nearest to discovered: walt, stoll, hydrochloric, greats, stubborn, negotiations, destroying, conforming,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6747 0.0237 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6716 0.0227 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6130 0.0231 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6135 0.0226 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6363 0.0231 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6575 0.0229 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5751 0.0175 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5484 0.0230 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5116 0.0232 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4967 0.0230 sec/batch
# Nearest to these: because, physical, evaluated, closely, problem, suited, travel, integration,
# Nearest to time: sambia, hilton, automobile, strengthen, advertisement, omnipotence, correcting, microscopes,
# Nearest to other: inhibiting, doings, coelacanth, animal, codec, herbs, ethers, dulles,
# Nearest to was: collaborators, people, astray, fall, devotion, cook, aronson, hydroplane,
# Nearest to american: poet, musician, chemist, physicist, nobel, actor, william, claude,
# Nearest to into: holocene, ape, valentinianism, worshipped, setae, table, preserve, offense,
# Nearest to are: freshness, prevenient, contradiction, axiom, rodents, mulholland, capita, conscripted,
# Nearest to have: unpleasantly, objectively, ladefoged, planing, sigh, lobbyist, dispatching, anson,
# Nearest to experience: distinctions, wellesley, restrict, syllable, auger, upstairs, chi, weismann,
# Nearest to pressure: caudillo, surrogate, breakdown, inaccurately, dewitt, focusing, tenures, analysing,
# Nearest to pre: wanted, stringent, eristic, outlasted, offer, knockout, invisibility, defying,
# Nearest to mainly: preserve, rejection, kepler, lucifer, gnu, container, fimbulwinter, miniatures,
# Nearest to police: longinus, rl, leadership, totoro, invoke, dion, charted, nasrani,
# Nearest to mathematics: huygens, arcturus, sepoy, outnumbered, utilitarian, sanders, hutchence, memetic,
# Nearest to bbc: quarrels, spinoff, kala, lycos, janis, couch, aerosol, slavery,
# Nearest to discovered: stoll, walt, greats, hydrochloric, canyon, conforming, stubborn, ezquerra,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4850 0.0237 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5178 0.0228 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4835 0.0229 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5562 0.0230 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5162 0.0227 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4782 0.0231 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4518 0.0227 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4065 0.0228 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4450 0.0228 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4049 0.0229 sec/batch
# Nearest to these: physical, because, evaluated, problem, closely, suited, integration, travel,
# Nearest to time: hilton, sambia, a, macbook, automobile, strengthen, microscopes, eaters,
# Nearest to other: inhibiting, doings, animal, coelacanth, codec, herbs, capacities, uses,
# Nearest to was: collaborators, aronson, astray, fall, hydroplane, norodom, evacuation, people,
# Nearest to american: poet, musician, gda, zal, physicist, nobel, academies, chemist,
# Nearest to into: holocene, ape, valentinianism, preserve, table, worshipped, setae, ludicrous,
# Nearest to are: freshness, prevenient, capita, weakens, rodents, noaa, axiom, placement,
# Nearest to have: unpleasantly, dispatching, objectively, lobbyist, tenet, sigh, amortized, planing,
# Nearest to experience: distinctions, wellesley, restrict, syllable, upstairs, auger, subtle, weismann,
# Nearest to pressure: caudillo, breakdown, surrogate, inaccurately, machinery, jackpots, dewitt, analysing,
# Nearest to pre: wanted, outlasted, eristic, offer, stringent, artesian, knockout, survival,
# Nearest to mainly: preserve, rejection, lucifer, kepler, container, fimbulwinter, miniatures, consults,
# Nearest to police: longinus, totoro, leadership, invoke, lewiec, rl, katrina, ties,
# Nearest to mathematics: huygens, arcturus, sepoy, utilitarian, animations, memetic, mutation, hutchence,
# Nearest to bbc: spinoff, quarrels, kala, lycos, couch, janis, bela, alcan,
# Nearest to discovered: stoll, hydrochloric, conforming, greats, walt, ezquerra, wideband, sacred,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4308 0.0239 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4083 0.0228 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4072 0.0230 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3814 0.0226 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4235 0.0228 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4318 0.0229 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3974 0.0232 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3748 0.0227 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4164 0.0228 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3903 0.0229 sec/batch
# Nearest to these: because, physical, evaluated, suited, closely, problem, travel, coughlin,
# Nearest to time: macbook, a, sambia, game, hilton, cornered, automobile, advertisement,
# Nearest to other: inhibiting, doings, animal, coelacanth, ethers, codec, accordance, maintaining,
# Nearest to was: collaborators, aronson, reign, finally, inscrutable, devotion, norodom, astray,
# Nearest to american: musician, zal, chemist, nobel, poet, gda, navigator, jeff,
# Nearest to into: holocene, ape, preserve, valentinianism, worshipped, setae, table, evo,
# Nearest to are: prevenient, freshness, capita, weakens, mulholland, noaa, rodents, axiom,
# Nearest to have: unpleasantly, objectively, amortized, dispatching, planing, sigh, ladefoged, lobbyist,
# Nearest to experience: distinctions, wellesley, restrict, weismann, syllable, upstairs, auger, whidbey,
# Nearest to pressure: breakdown, surrogate, caudillo, inaccurately, decreases, machinery, jackpots, microscopy,
# Nearest to pre: wanted, eristic, outlasted, catastrophism, offer, knockout, stringent, invisibility,
# Nearest to mainly: preserve, lucifer, rejection, fimbulwinter, kepler, gallen, container, frontispiece,
# Nearest to police: longinus, totoro, leadership, katrina, lewiec, invoke, ties, lend,
# Nearest to mathematics: huygens, utilitarian, arcturus, sepoy, animations, mutation, finite, memetic,
# Nearest to bbc: spinoff, lycos, kala, quarrels, couch, janis, bela, gunfighter,
# Nearest to discovered: stoll, hydrochloric, ezquerra, wideband, conforming, encountered, sacred, teaspoon,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3688 0.0239 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3752 0.0228 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3479 0.0229 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3539 0.0227 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3764 0.0227 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3751 0.0228 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3592 0.0230 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3658 0.0227 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2987 0.0228 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3257 0.0228 sec/batch
# Nearest to these: because, evaluated, suited, physical, closely, coughlin, adipose, purely,
# Nearest to time: cornered, sambia, macbook, cogs, strengthen, curule, a, advertisement,
# Nearest to other: inhibiting, doings, animal, coelacanth, ethers, maintaining, interests, accordance,
# Nearest to was: inscrutable, reign, collaborators, norodom, salinas, pharmacologist, missions, evacuation,
# Nearest to american: zal, navigator, helen, musician, gda, dina, dillon, capitulation,
# Nearest to into: holocene, ape, preserve, valentinianism, evo, worshipped, setae, aloha,
# Nearest to are: prevenient, freshness, mulholland, capita, noaa, rodents, lemonade, weakens,
# Nearest to have: amortized, objectively, planing, unpleasantly, uploading, dispatching, sigh, huckleberry,
# Nearest to experience: distinctions, restrict, wellesley, whidbey, weismann, subtle, hannity, inanimate,
# Nearest to pressure: breakdown, caudillo, surrogate, inaccurately, machinery, jackpots, decreases, crystals,
# Nearest to pre: wanted, outlasted, eristic, speakers, catastrophism, stringent, artesian, offer,
# Nearest to mainly: preserve, lucifer, indian, fimbulwinter, indigenous, container, rejection, gallen,
# Nearest to police: totoro, longinus, katrina, leadership, lend, dion, ties, nasrani,
# Nearest to mathematics: huygens, arcturus, utilitarian, sepoy, geometric, surmised, proofs, memetic,
# Nearest to bbc: spinoff, lycos, couch, quarrels, bela, gunfighter, janis, otho,
# Nearest to discovered: stoll, hydrochloric, ezquerra, conforming, wideband, encountered, sacred, canyon,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3398 0.0239 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2610 0.0230 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3796 0.0229 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3655 0.0231 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3972 0.0228 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3132 0.0230 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2993 0.0229 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3292 0.0229 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2169 0.0231 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2792 0.0230 sec/batch
# Nearest to these: because, evaluated, codas, physical, adipose, coughlin, problem, closely,
# Nearest to time: cornered, sambia, macbook, curule, strengthen, svoboda, cogs, return,
# Nearest to other: inhibiting, doings, ethers, animal, coelacanth, kalahari, codec, maintaining,
# Nearest to was: when, salinas, inscrutable, norodom, campaign, midget, koninklijke, pharmacologist,
# Nearest to american: musician, chemist, navigator, nobel, actor, golfer, zal, helen,
# Nearest to into: holocene, preserve, ape, evo, valentinianism, worshipped, setae, enthusiastic,
# Nearest to are: prevenient, mulholland, capita, freshness, noaa, rodents, lemonade, native,
# Nearest to have: amortized, objectively, planing, uploading, unpleasantly, pervasive, dispatching, huckleberry,
# Nearest to experience: distinctions, wellesley, restrict, weismann, whidbey, comments, upstairs, hannity,
# Nearest to pressure: breakdown, caudillo, inaccurately, surrogate, jackpots, machinery, dewitt, unreliability,
# Nearest to pre: wanted, eristic, outlasted, speakers, stringent, catastrophism, artesian, offer,
# Nearest to mainly: preserve, indigenous, groups, container, indian, growth, fimbulwinter, rejection,
# Nearest to police: totoro, katrina, nasrani, leadership, lend, welland, fruitarians, lewiec,
# Nearest to mathematics: huygens, arcturus, utilitarian, fermat, proofs, surmised, memetic, sepoy,
# Nearest to bbc: lycos, spinoff, belarussian, bela, janis, otho, quarrels, couch,
# Nearest to discovered: stoll, ezquerra, hydrochloric, canyon, conforming, wideband, teaspoon, baserunners,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2927 0.0239 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2961 0.0228 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3433 0.0119 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2274 0.0234 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2138 0.0236 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2233 0.0232 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2289 0.0231 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2209 0.0231 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2396 0.0229 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1707 0.0228 sec/batch
# Nearest to these: because, evaluated, closely, codas, coughlin, suited, adipose, problem,
# Nearest to time: cornered, cogs, return, macbook, sambia, hilton, a, frink,
# Nearest to other: ethers, animal, inhibiting, coelacanth, doings, codec, kalahari, herbs,
# Nearest to was: when, inscrutable, salinas, astray, rsi, norodom, somehow, evacuation,
# Nearest to american: zal, navigator, musician, golfer, dina, nobel, helen, gda,
# Nearest to into: holocene, ape, preserve, setae, evo, valentinianism, worshipped, violet,
# Nearest to are: prevenient, rodents, freshness, lemonade, capita, mulholland, noaa, native,
# Nearest to have: amortized, objectively, planing, unpleasantly, dispatching, charger, sigh, uploading,
# Nearest to experience: distinctions, wellesley, restrict, subtle, upstairs, whidbey, weismann, hannity,
# Nearest to pressure: breakdown, caudillo, inaccurately, surrogate, jackpots, machinery, epidemic, unreliability,
# Nearest to pre: wanted, eristic, speakers, artesian, outlasted, catastrophism, offer, invisibility,
# Nearest to mainly: preserve, groups, indigenous, fimbulwinter, principally, indian, growth, rejection,
# Nearest to police: totoro, katrina, lend, nasrani, fruitarians, welland, plze, leadership,
# Nearest to mathematics: huygens, arcturus, utilitarian, fermat, proofs, surmised, memetic, sepoy,
# Nearest to bbc: lycos, spinoff, otho, kala, bela, belarussian, quarrels, estis,
# Nearest to discovered: stoll, teaspoon, ezquerra, canyon, hydrochloric, thrive, conforming, baserunners,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2518 0.0237 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2253 0.0226 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2208 0.0229 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1145 0.0227 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1625 0.0228 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1737 0.0227 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1476 0.0231 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1910 0.0233 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2035 0.0232 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1837 0.0233 sec/batch
# Nearest to these: because, evaluated, adipose, codas, suited, closely, purely, problem,
# Nearest to time: macbook, cornered, return, cogs, hilton, game, palmas, gms,
# Nearest to other: inhibiting, animal, ethers, doings, maintaining, uses, such, codec,
# Nearest to was: when, norodom, somehow, rsi, salinas, cannon, astray, pharmacologist,
# Nearest to american: zal, navigator, dina, gda, golfer, musician, ballplayers, nimo,
# Nearest to into: holocene, preserve, with, evo, setae, ape, valentinianism, violet,
# Nearest to are: prevenient, rodents, capita, freshness, stimulus, noaa, weakens, native,
# Nearest to have: objectively, amortized, planing, unpleasantly, gallup, charger, dispatching, sigh,
# Nearest to experience: distinctions, restrict, wellesley, whidbey, upstairs, hannity, subtle, haereses,
# Nearest to pressure: breakdown, inaccurately, caudillo, surrogate, gives, jackpots, anemometers, confirmed,
# Nearest to pre: wanted, speakers, eristic, outlasted, catastrophism, artesian, filenames, invisibility,
# Nearest to mainly: preserve, groups, growth, indian, principally, indigenous, journeymen, fimbulwinter,
# Nearest to police: katrina, totoro, lend, fruitarians, welland, invoke, nasrani, rl,
# Nearest to mathematics: huygens, arcturus, fermat, utilitarian, proofs, surmised, sepoy, memetic,
# Nearest to bbc: lycos, spinoff, otho, pbs, belarussian, bela, kala, embezzlement,
# Nearest to discovered: stoll, teaspoon, ezquerra, canyon, baserunners, hydrochloric, thrive, lumpy,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1983 0.0243 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2414 0.0233 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1743 0.0235 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1333 0.0231 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1603 0.0232 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1934 0.0231 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2113 0.0233 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1411 0.0230 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1387 0.0229 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1746 0.0234 sec/batch
# Nearest to these: because, codas, adipose, closely, suited, purely, evaluated, coughlin,
# Nearest to time: cogs, a, cornered, gms, macbook, return, palmas, game,
# Nearest to other: ethers, inhibiting, animal, doings, uses, coelacanth, passion, codec,
# Nearest to was: when, norodom, salinas, pharmacologist, reign, somehow, aquileia, clonaid,
# Nearest to american: zal, navigator, musician, dina, golfer, hamill, nimo, gda,
# Nearest to into: holocene, preserve, setae, ape, evo, with, worshipped, enthusiastic,
# Nearest to are: prevenient, rodents, freshness, capita, lemonade, stimulus, mulholland, placement,
# Nearest to have: amortized, objectively, planing, sigh, unpleasantly, gallup, pervasive, dispatching,
# Nearest to experience: distinctions, restrict, wellesley, haereses, weismann, whidbey, upstairs, hannity,
# Nearest to pressure: breakdown, caudillo, jackpots, inaccurately, surrogate, unreliability, confirmed, anemometers,
# Nearest to pre: wanted, eristic, speakers, filenames, artesian, catastrophism, stringent, reintroduction,
# Nearest to mainly: preserve, groups, principally, growth, indigenous, indian, fimbulwinter, rejection,
# Nearest to police: katrina, totoro, lend, welland, leadership, ties, dion, nasrani,
# Nearest to mathematics: fermat, huygens, arcturus, utilitarian, proofs, surmised, phys, cole,
# Nearest to bbc: lycos, spinoff, otho, pbs, articles, belarussian, bela, embezzlement,
# Nearest to discovered: stoll, baserunners, canyon, lumpy, hydrochloric, ezquerra, teaspoon, thrive,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2021 0.0241 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1861 0.0233 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1854 0.0230 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1657 0.0230 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1479 0.0231 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1269 0.0229 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1904 0.0232 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0908 0.0231 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2304 0.0230 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2309 0.0237 sec/batch
# Nearest to these: because, coughlin, codas, closely, evaluated, adipose, suited, problem,
# Nearest to time: cornered, cogs, a, return, gms, snegur, palmas, frink,
# Nearest to other: ethers, doings, animal, passion, dulles, coelacanth, inhibiting, maintaining,
# Nearest to was: when, salinas, norodom, pharmacologist, aquileia, somehow, reign, operatic,
# Nearest to american: musician, zal, actor, navigator, nobel, golfer, chemist, physicist,
# Nearest to into: holocene, preserve, partly, aloha, evo, with, indonesians, to,
# Nearest to are: prevenient, capita, rodents, lemonade, native, mulholland, freshness, kingman,
# Nearest to have: objectively, amortized, gallup, planing, pervasive, charger, throwback, sigh,
# Nearest to experience: distinctions, wellesley, restrict, haereses, revolves, whidbey, weismann, upstairs,
# Nearest to pressure: breakdown, caudillo, jackpots, unreliability, inaccurately, confirmed, anemometers, surrogate,
# Nearest to pre: wanted, speakers, eristic, artesian, stringent, filenames, outlasted, catastrophism,
# Nearest to mainly: preserve, indian, principally, groups, indigenous, fimbulwinter, hunsr, journeymen,
# Nearest to police: katrina, totoro, lend, dion, fruitarians, nasrani, welland, leadership,
# Nearest to mathematics: arcturus, fermat, huygens, utilitarian, proofs, surmised, journeying, cole,
# Nearest to bbc: lycos, pbs, otho, spinoff, belarussian, articles, estis, embezzlement,
# Nearest to discovered: stoll, canyon, lumpy, elephas, baserunners, hanged, teaspoon, thrive,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2224 0.0240 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1531 0.0231 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1677 0.0229 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1279 0.0228 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0600 0.0234 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1317 0.0233 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1590 0.0235 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1346 0.0233 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1716 0.0061 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1085 0.0233 sec/batch
# Nearest to these: adipose, codas, because, coughlin, suited, evaluated, closely, sizing,
# Nearest to time: cogs, a, gms, cornered, kusanagi, macbook, frink, return,
# Nearest to other: ethers, doings, animal, such, coelacanth, maintaining, inhibiting, passion,
# Nearest to was: when, somehow, operatic, aquileia, tanistry, salinas, megabytes, contributed,
# Nearest to american: musician, zal, navigator, dina, golfer, actor, hamill, ballplayers,
# Nearest to into: holocene, with, partly, preserve, indonesians, valentinianism, setae, to,
# Nearest to are: prevenient, rodents, lemonade, capita, native, freshness, mulholland, kingman,
# Nearest to have: amortized, objectively, gallup, planing, throwback, charger, franchisees, uploading,
# Nearest to experience: wellesley, revolves, distinctions, restrict, haereses, weismann, whidbey, sais,
# Nearest to pressure: breakdown, caudillo, jackpots, delivers, inaccurately, unreliability, confirmed, tenures,
# Nearest to pre: wanted, eristic, speakers, filenames, artesian, stringent, outlasted, catastrophism,
# Nearest to mainly: preserve, principally, indian, groups, indigenous, glossary, fimbulwinter, hunsr,
# Nearest to police: katrina, lend, totoro, nasrani, fruitarians, dion, blocking, abstained,
# Nearest to mathematics: fermat, arcturus, huygens, utilitarian, proofs, journeying, phys, cole,
# Nearest to bbc: lycos, pbs, otho, belarussian, articles, spinoff, estis, january,
# Nearest to discovered: stoll, canyon, baserunners, lumpy, elephas, teaspoon, hydrochloric, thrive,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0644 0.0245 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0448 0.0233 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0883 0.0232 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0518 0.0233 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0947 0.0232 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0572 0.0233 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1076 0.0235 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0799 0.0233 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1243 0.0230 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0137 0.0231 sec/batch
# Nearest to these: adipose, because, suited, codas, sizing, purely, coughlin, evaluated,
# Nearest to time: cogs, a, macbook, return, gms, removable, kusanagi, opteron,
# Nearest to other: ethers, such, animal, inhibiting, coelacanth, maintaining, passion, doings,
# Nearest to was: when, aquileia, rus, salinas, reign, rsi, somehow, operatic,
# Nearest to american: zal, dina, navigator, musician, ballplayers, islander, golfer, nimo,
# Nearest to into: holocene, with, partly, indonesians, preserve, worshipped, valentinianism, greeks,
# Nearest to are: prevenient, rodents, capita, lemonade, native, freshness, or, weakens,
# Nearest to have: amortized, objectively, planing, charger, cavern, dispatching, throwback, unpleasantly,
# Nearest to experience: wellesley, revolves, whidbey, restrict, distinctions, weismann, haereses, whedon,
# Nearest to pressure: breakdown, caudillo, jackpots, anemometers, unreliability, inaccurately, tenures, delivers,
# Nearest to pre: wanted, eristic, speakers, outlasted, artesian, filenames, stringent, catastrophism,
# Nearest to mainly: preserve, principally, indian, growth, hunsr, groups, fimbulwinter, indigenous,
# Nearest to police: katrina, lend, totoro, fruitarians, nasrani, blocking, abstained, seijuro,
# Nearest to mathematics: fermat, arcturus, huygens, utilitarian, journeying, cole, proofs, schopenhauer,
# Nearest to bbc: lycos, pbs, programmes, otho, broadcasting, broadcasts, belarussian, articles,
# Nearest to discovered: stoll, lumpy, canyon, teaspoon, baserunners, elephas, hanged, sequenced,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0071 0.0242 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0489 0.0234 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0041 0.0234 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0686 0.0228 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0717 0.0231 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0452 0.0232 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0491 0.0234 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1351 0.0232 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0203 0.0229 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0634 0.0230 sec/batch
# Nearest to these: adipose, because, suited, sockets, codas, closely, evaluated, purely,
# Nearest to time: cogs, return, a, gms, opteron, macbook, hints, frink,
# Nearest to other: ethers, animal, such, passion, doings, maintaining, coelacanth, inhibiting,
# Nearest to was: when, operatic, somehow, megabytes, salinas, aquileia, tanistry, geophysical,
# Nearest to american: zal, dina, musician, navigator, nimo, islander, ballplayers, jeff,
# Nearest to into: holocene, partly, to, aloha, setae, worshipped, indonesians, preserve,
# Nearest to are: prevenient, or, rodents, capita, couples, distinguishing, native, lemonade,
# Nearest to have: objectively, amortized, cavern, amenable, sigh, charger, throwback, gallup,
# Nearest to experience: wellesley, restrict, revolves, detect, whedon, distinctions, whidbey, hannity,
# Nearest to pressure: breakdown, caudillo, jackpots, delivers, anemometers, unreliability, gives, tenures,
# Nearest to pre: wanted, eristic, speakers, filenames, artesian, outlasted, anticipation, invisibility,
# Nearest to mainly: principally, preserve, indian, growth, telluride, hunsr, glossary, groups,
# Nearest to police: lend, totoro, katrina, fruitarians, nasrani, invoke, blocking, welland,
# Nearest to mathematics: fermat, arcturus, utilitarian, huygens, journeying, phys, cole, proofs,
# Nearest to bbc: lycos, pbs, programmes, broadcasts, otho, broadcasting, articles, belarussian,
# Nearest to discovered: stoll, lumpy, canyon, teaspoon, baserunners, sequenced, condense, peano,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0906 0.0238 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0853 0.0231 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0844 0.0236 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0547 0.0229 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0745 0.0234 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0662 0.0237 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0660 0.0233 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0656 0.0233 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0666 0.0235 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0762 0.0235 sec/batch
# Nearest to these: adipose, because, codas, evaluated, purely, closely, sizing, sockets,
# Nearest to time: cogs, return, gms, cornered, a, hilton, hints, opteron,
# Nearest to other: ethers, animal, such, passion, volvo, kalahari, dulles, witted,
# Nearest to was: when, aquileia, tanistry, reign, rus, salinas, operatic, agreed,
# Nearest to american: zal, dina, navigator, islander, ballplayers, nimo, musician, jw,
# Nearest to into: holocene, partly, preserve, cysteine, indonesians, disaccharide, aloha, outside,
# Nearest to are: prevenient, capita, rodents, lemonade, native, or, freshness, mulholland,
# Nearest to have: objectively, amortized, cavern, sigh, charger, amenable, gallup, planing,
# Nearest to experience: wellesley, revolves, restrict, haereses, distinctions, whidbey, detect, hannity,
# Nearest to pressure: breakdown, jackpots, caudillo, delivers, anemometers, dore, unreliability, moray,
# Nearest to pre: wanted, eristic, filenames, speakers, stringent, artesian, outlasted, anticipation,
# Nearest to mainly: principally, preserve, indian, glossary, hunsr, telluride, journeymen, ssr,
# Nearest to police: fruitarians, katrina, lend, totoro, nasrani, blocking, abstained, welland,
# Nearest to mathematics: arcturus, fermat, huygens, utilitarian, journeying, cole, proofs, phys,
# Nearest to bbc: pbs, lycos, articles, programmes, otho, broadcasts, belarussian, day,
# Nearest to discovered: stoll, lumpy, sequenced, canyon, baserunners, peano, teaspoon, elephas,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0298 0.0247 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0073 0.0233 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0482 0.0234 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0767 0.0235 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0962 0.0233 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1343 0.0231 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1291 0.0232 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0354 0.0233 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0137 0.0230 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0696 0.0232 sec/batch
# Nearest to these: codas, evaluated, adipose, because, purely, sockets, closely, sizing,
# Nearest to time: cogs, return, a, gms, opteron, hilton, kusanagi, hints,
# Nearest to other: ethers, such, animal, inhibiting, maintaining, passion, kalahari, dulles,
# Nearest to was: when, aquileia, operatic, somehow, replacement, salinas, contributed, pharmacologist,
# Nearest to american: zal, dina, islander, musician, navigator, jw, hamill, nimo,
# Nearest to into: holocene, indonesians, to, partly, with, aloha, cysteine, preserve,
# Nearest to are: prevenient, capita, native, lemonade, rodents, or, tagalog, basic,
# Nearest to have: objectively, gallup, been, amortized, sigh, throwback, cavern, animosity,
# Nearest to experience: wellesley, revolves, detect, auger, haereses, restrict, whidbey, upstairs,
# Nearest to pressure: breakdown, jackpots, delivers, caudillo, dore, unreliability, anemometers, tenures,
# Nearest to pre: wanted, eristic, speakers, stringent, filenames, artesian, outlasted, anticipation,
# Nearest to mainly: preserve, indian, principally, hunsr, glossary, ancestry, telluride, groups,
# Nearest to police: fruitarians, totoro, katrina, patrol, lend, nasrani, welland, leadership,
# Nearest to mathematics: arcturus, fermat, journeying, huygens, utilitarian, cole, balkans, proofs,
# Nearest to bbc: pbs, lycos, day, belarussian, otho, articles, programmes, broadcasts,
# Nearest to discovered: stoll, lumpy, canyon, sequenced, baserunners, elephas, teaspoon, sukarnoputri,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9585 0.0240 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0329 0.0232 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0330 0.0229 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0590 0.0232 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0796 0.0231 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0328 0.0235 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0055 0.0233 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9692 0.0233 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0247 0.0229 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9550 0.0230 sec/batch
# Nearest to these: codas, adipose, sizing, closely, sockets, evaluated, coughlin, suited,
# Nearest to time: cogs, return, a, kusanagi, opteron, hints, hilton, gms,
# Nearest to other: ethers, animal, such, doings, gematria, passion, coelacanth, kalahari,
# Nearest to was: when, aquileia, tanistry, rus, versions, operatic, but, megabytes,
# Nearest to american: zal, dina, islander, musician, navigator, jw, hamill, golfer,
# Nearest to into: holocene, indonesians, to, with, partly, worshipped, palenque, acadian,
# Nearest to are: prevenient, lemonade, rodents, capita, freshness, distinguishing, tagalog, basic,
# Nearest to have: objectively, cavern, been, animosity, sigh, amortized, gallup, throwback,
# Nearest to experience: wellesley, revolves, restrict, whidbey, haereses, upstairs, detect, whedon,
# Nearest to pressure: breakdown, jackpots, delivers, caudillo, dore, anemometers, moray, unreliability,
# Nearest to pre: wanted, eristic, speakers, filenames, outlasted, artesian, anticipation, stringent,
# Nearest to mainly: preserve, glossary, principally, indian, hunsr, telluride, journeymen, rejection,
# Nearest to police: totoro, fruitarians, lend, katrina, patrol, nasrani, blocking, invoke,
# Nearest to mathematics: arcturus, fermat, journeying, utilitarian, cole, huygens, balkans, phys,
# Nearest to bbc: pbs, lycos, day, listing, belarussian, programmes, otho, broadcasts,
# Nearest to discovered: stoll, lumpy, sequenced, canyon, baserunners, condense, geographie, peano,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0020 0.0241 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9479 0.0231 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0175 0.0232 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0013 0.0234 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0395 0.0232 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9769 0.0232 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8958 0.0234 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9684 0.0227 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9023 0.0229 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9801 0.0227 sec/batch
# Nearest to these: codas, sizing, closely, adipose, of, purely, sockets, lamas,
# Nearest to time: a, cogs, return, hilton, before, kusanagi, gms, hints,
# Nearest to other: ethers, animal, such, include, gematria, passion, maintaining, abounds,
# Nearest to was: when, aquileia, replacement, versions, rus, megabytes, tanistry, operatic,
# Nearest to american: zal, islander, dina, jw, navigator, nimo, tabla, coelacanth,
# Nearest to into: holocene, to, with, indonesians, partly, worshipped, them, disaccharide,
# Nearest to are: prevenient, lemonade, or, capita, rodents, basic, freshness, native,
# Nearest to have: been, cavern, objectively, amenable, animosity, unpleasantly, gallup, throwback,
# Nearest to experience: wellesley, revolves, upstairs, whedon, haereses, whidbey, detect, restrict,
# Nearest to pressure: breakdown, jackpots, delivers, anemometers, caudillo, unreliability, dore, forfeit,
# Nearest to pre: wanted, eristic, speakers, artesian, outlasted, anticipation, pcs, filenames,
# Nearest to mainly: preserve, hunsr, indian, telluride, principally, glossary, journeymen, afro,
# Nearest to police: totoro, fruitarians, patrol, katrina, nasrani, lend, welland, invoke,
# Nearest to mathematics: arcturus, fermat, journeying, utilitarian, cole, huygens, phys, balkans,
# Nearest to bbc: pbs, lycos, broadcasts, listing, programmes, belarussian, otho, allafrica,
# Nearest to discovered: stoll, sequenced, lumpy, discoveries, peano, canyon, condense, teaspoon,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9940 0.0242 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9719 0.0227 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9950 0.0230 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0112 0.0232 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0147 0.0236 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9454 0.0237 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9974 0.0234 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0021 0.0232 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9897 0.0230 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9976 0.0233 sec/batch
# Nearest to these: of, evaluated, adipose, because, sizing, sockets, closely, purely,
# Nearest to time: a, return, cogs, gms, before, hints, destination, hilton,
# Nearest to other: ethers, animal, such, include, passion, gematria, maintaining, blurring,
# Nearest to was: when, operatic, aquileia, rus, tanistry, contributed, replacement, pharmacologist,
# Nearest to american: zal, musician, islander, nimo, navigator, dina, jw, tabla,
# Nearest to into: holocene, to, indonesians, partly, with, cysteine, worshipped, disaccharide,
# Nearest to are: prevenient, basic, or, capita, lemonade, fluently, distinguishing, rodents,
# Nearest to have: been, objectively, cavern, sigh, throwback, gallup, animosity, amenable,
# Nearest to experience: wellesley, revolves, whedon, haereses, restrict, detect, experiences, whidbey,
# Nearest to pressure: breakdown, delivers, jackpots, anemometers, caudillo, unreliability, dore, forfeit,
# Nearest to pre: wanted, eristic, anticipation, pcs, speakers, oxidise, asparagales, artesian,
# Nearest to mainly: hunsr, indian, preserve, telluride, principally, afro, ancestry, glossary,
# Nearest to police: totoro, fruitarians, lend, patrol, nasrani, katrina, welland, government,
# Nearest to mathematics: arcturus, fermat, utilitarian, journeying, huygens, cole, phys, balkans,
# Nearest to bbc: pbs, lycos, listing, day, programmes, broadcasts, belarussian, otho,
# Nearest to discovered: stoll, sequenced, discoveries, lumpy, peano, discovery, cushing, canyon,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0101 0.0240 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9826 0.0231 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9885 0.0229 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0049 0.0230 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0314 0.0231 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0077 0.0231 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9958 0.0232 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9667 0.0232 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9564 0.0231 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0181 0.0231 sec/batch
# Nearest to these: adipose, codas, of, because, coughlin, whereabouts, sizing, closely,
# Nearest to time: a, return, gms, cogs, before, hilton, sowed, bubiyan,
# Nearest to other: ethers, animal, such, include, includes, maintaining, gematria, recognize,
# Nearest to was: when, aquileia, agreed, operatic, tanistry, megabytes, rus, replacement,
# Nearest to american: zal, musician, islander, dina, navigator, nimo, jw, larisa,
# Nearest to into: holocene, to, with, partly, indonesians, cysteine, worshipped, which,
# Nearest to are: prevenient, lemonade, or, basic, native, capita, tagalog, fluently,
# Nearest to have: been, objectively, cavern, gallup, animosity, amenable, sigh, pervasive,
# Nearest to experience: wellesley, whidbey, revolves, whedon, detect, egotistical, haereses, upstairs,
# ...
# Nearest to these: of, been, many, some, has, such, are, fills,
# Nearest to time: before, a, the, when, preset, for, ampex, destination,
# Nearest to other: of, include, well, such, are, and, with, similar,
# Nearest to was: were, when, became, but, been, he, in, first,
# Nearest to american: zal, islander, nimo, aerospace, spingarn, filipino, jw, veterans,
# Nearest to into: to, the, which, and, another, called, become, with,
# Nearest to are: or, there, in, some, their, other, similar, be,
# Nearest to have: been, or, and, also, objectively, are, these, other,
# Nearest to experience: wellesley, experiences, strategist, saale, acquisition, delusion, impassioned, laval,
# Nearest to pressure: breakdown, outlets, bhutto, forfeit, harun, unscathed, dore, anemometers,
# Nearest to pre: wanted, anticipation, unearth, ministerio, zooming, cundinamarca, schmitt, cycladic,
# Nearest to mainly: attempts, telluride, especially, principally, hunsr, ancestry, malthusian, arranged,
# Nearest to police: patrol, government, champ, diffuse, spirited, hurtful, entrenchment, resolves,
# Nearest to mathematics: arcturus, fermat, journeying, arithmetica, dtft, prodigies, cole, anthemius,
# Nearest to bbc: programmes, pbs, broadcasts, listing, aerosol, day, lycos, iss,
# Nearest to discovered: discovery, discoveries, hangovers, stoll, sequenced, paracelsus, peano, valuable,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8197 0.0242 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8427 0.0231 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8353 0.0227 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8907 0.0229 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8557 0.0231 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8718 0.0231 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8466 0.0228 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8490 0.0229 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8583 0.0230 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8751 0.0230 sec/batch
# Nearest to these: of, many, been, some, has, even, most, are,
# Nearest to time: before, a, destination, the, shuja, when, solstice, preset,
# Nearest to other: of, well, include, such, are, and, with, recognize,
# Nearest to was: were, became, when, but, the, in, been, he,
# Nearest to american: zal, islander, veterans, aerospace, filipino, nimo, americans, spingarn,
# Nearest to into: to, the, and, which, another, williamsburg, of, from,
# Nearest to are: or, there, in, some, other, is, example, similar,
# Nearest to have: been, or, also, and, objectively, ebu, recent, other,
# Nearest to experience: wellesley, experiences, saale, strategist, acquisition, empowering, laval, impassioned,
# Nearest to pressure: bhutto, breakdown, outlets, forfeit, harun, dore, anscombe, unscathed,
# Nearest to pre: unearth, anticipation, wanted, cundinamarca, ministerio, schmitt, cycladic, zooming,
# Nearest to mainly: attempts, especially, principally, telluride, hunsr, starchy, arranged, malthusian,
# Nearest to police: patrol, government, champ, diffuse, spirited, resolves, entrenchment, crosstalk,
# Nearest to mathematics: arcturus, fermat, journeying, arithmetica, cole, prodigies, dtft, anthemius,
# Nearest to bbc: programmes, pbs, broadcasts, listing, aerosol, day, lycos, iss,
# Nearest to discovered: discovery, discoveries, hangovers, stoll, paracelsus, bombarding, sequenced, rfloor,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8709 0.0240 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8294 0.0228 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8324 0.0228 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8067 0.0228 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9242 0.0229 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8437 0.0229 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9467 0.0231 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9226 0.0227 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9091 0.0228 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8206 0.0227 sec/batch
# Nearest to these: of, some, been, many, such, has, are, most,
# Nearest to time: before, when, a, shuja, was, lived, the, destination,
# Nearest to other: of, well, include, such, and, are, list, with,
# Nearest to was: when, were, became, in, he, but, been, the,
# Nearest to american: zal, islander, veterans, filipino, spingarn, aerospace, nimo, jw,
# Nearest to into: to, the, which, of, and, another, from, with,
# Nearest to are: there, or, is, in, some, other, similar, unlike,
# Nearest to have: been, or, and, also, that, objectively, kellerman, ebu,
# Nearest to experience: wellesley, experiences, strategist, saale, empowering, impassioned, delusion, laval,
# Nearest to pressure: bhutto, breakdown, surge, outlets, unscathed, harun, forfeit, dore,
# Nearest to pre: unearth, anticipation, ministerio, cundinamarca, wanted, schmitt, cycladic, violating,
# Nearest to mainly: attempts, especially, principally, ancestry, icelanders, arranged, starchy, hunsr,
# Nearest to police: patrol, government, champ, diffuse, spirited, jaeger, ubs, hurtful,
# Nearest to mathematics: arcturus, fermat, journeying, arithmetica, prodigies, cole, dtft, anthemius,
# Nearest to bbc: programmes, pbs, broadcasts, listing, day, aerosol, iss, belarussian,
# Nearest to discovered: discovery, hangovers, discoveries, stoll, bombarding, paracelsus, valuable, sequenced,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8414 0.0238 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8261 0.0230 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8176 0.0227 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8718 0.0230 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8488 0.0229 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8784 0.0233 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8625 0.0179 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8421 0.0238 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8244 0.0232 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8723 0.0232 sec/batch
# Nearest to these: many, of, some, been, such, fills, most, are,
# Nearest to time: before, was, the, a, at, when, shuja, destination,
# Nearest to other: of, include, well, such, are, with, and, in,
# Nearest to was: when, but, became, were, he, the, been, in,
# Nearest to american: zal, islander, filipino, spingarn, jw, veterans, localised, golfer,
# Nearest to into: to, the, from, another, and, which, called, with,
# Nearest to are: or, there, in, is, some, other, example, any,
# Nearest to have: been, or, also, are, and, that, other, there,
# Nearest to experience: wellesley, strategist, saale, experiences, empowering, acquisition, flamboyant, delusion,
# Nearest to pressure: bhutto, breakdown, outlets, unscathed, surge, harun, dore, anscombe,
# Nearest to pre: unearth, anticipation, wanted, zooming, schmitt, ministerio, cundinamarca, violating,
# Nearest to mainly: attempts, principally, especially, ancestry, arranged, malthusian, starchy, gimme,
# Nearest to police: patrol, government, champ, spirited, diffuse, hurtful, jaeger, supercomputer,
# Nearest to mathematics: arcturus, journeying, fermat, arithmetica, prodigies, cole, anthemius, dtft,
# Nearest to bbc: programmes, pbs, broadcasts, listing, aerosol, day, iss, biology,
# Nearest to discovered: discovery, hangovers, stoll, discoveries, paracelsus, bombarding, valuable, rfloor,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8169 0.0240 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8288 0.0230 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7690 0.0235 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8737 0.0230 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8409 0.0234 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8448 0.0233 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8307 0.0234 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7180 0.0234 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7964 0.0233 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7651 0.0231 sec/batch
# Nearest to these: of, some, been, many, even, such, are, most,
# Nearest to time: before, the, a, at, shuja, when, preset, rarefied,
# Nearest to other: include, of, are, and, well, with, such, the,
# Nearest to was: were, became, but, when, been, he, in, first,
# Nearest to american: zal, islander, localised, spingarn, nimo, faces, aerospace, jw,
# Nearest to into: to, the, from, which, and, called, another, with,
# Nearest to are: or, in, there, some, is, other, for, and,
# Nearest to have: been, or, also, and, that, are, other, than,
# Nearest to experience: wellesley, strategist, experiences, saale, empowering, delusion, acquisition, flamboyant,
# Nearest to pressure: breakdown, bhutto, outlets, unscathed, dore, anscombe, forfeit, anemometers,
# Nearest to pre: unearth, cundinamarca, ministerio, wanted, schmitt, anticipation, zooming, accentuate,
# Nearest to mainly: attempts, principally, especially, telluride, ancestry, starchy, malthusian, hunsr,
# Nearest to police: patrol, government, spirited, champ, diffuse, hurtful, supercomputer, entrenchment,
# Nearest to mathematics: arcturus, journeying, fermat, arithmetica, prodigies, cole, dtft, anthemius,
# Nearest to bbc: programmes, broadcasts, pbs, aerosol, listing, biology, belarussian, iss,
# Nearest to discovered: discovery, hangovers, discoveries, stoll, bombarding, paracelsus, peano, amicable,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7790 0.0242 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8135 0.0233 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8596 0.0233 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8319 0.0230 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8372 0.0234 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9137 0.0231 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8338 0.0232 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8469 0.0231 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8271 0.0234 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8151 0.0233 sec/batch
# Nearest to these: of, been, some, many, even, such, are, has,
# Nearest to time: before, the, a, at, when, shuja, preset, destination,
# Nearest to other: of, include, well, are, and, with, such, the,
# Nearest to was: became, were, in, when, but, been, he, later,
# Nearest to american: zal, islander, nimo, spingarn, veterans, americans, jw, localised,
# Nearest to into: to, another, which, from, the, and, called, with,
# Nearest to are: or, there, some, in, their, other, example, is,
# Nearest to have: been, or, also, and, than, are, that, recent,
# Nearest to experience: wellesley, strategist, saale, experiences, acquisition, delusion, neurological, empowering,
# Nearest to pressure: breakdown, bhutto, anscombe, unscathed, surge, dore, outlets, harun,
# Nearest to pre: unearth, wanted, zooming, anticipation, cundinamarca, schmitt, violating, ministerio,
# Nearest to mainly: attempts, especially, principally, telluride, ancestry, starchy, gimme, malthusian,
# Nearest to police: patrol, government, champ, diffuse, spirited, hurtful, criminal, supercomputer,
# Nearest to mathematics: arcturus, journeying, fermat, arithmetica, cole, prodigies, dtft, anthemius,
# Nearest to bbc: programmes, broadcasts, pbs, aerosol, listing, biology, belarussian, lycos,
# Nearest to discovered: discovery, discoveries, hangovers, bombarding, confirmed, paracelsus, stoll, amicable,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8522 0.0244 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8773 0.0236 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8396 0.0235 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8272 0.0231 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8590 0.0230 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8355 0.0229 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8681 0.0233 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8174 0.0231 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7892 0.0234 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8275 0.0233 sec/batch
# Nearest to these: of, some, many, are, been, such, has, most,
# Nearest to time: before, the, was, at, shuja, lived, a, when,
# Nearest to other: well, of, include, are, and, such, with, often,
# Nearest to was: became, but, were, when, in, the, been, he,
# Nearest to american: islander, zal, veterans, americans, nimo, spingarn, localised, filipino,
# Nearest to into: to, the, and, which, of, another, from, with,
# Nearest to are: or, there, is, some, in, other, example, these,
# Nearest to have: been, or, also, are, and, than, to, other,
# Nearest to experience: wellesley, strategist, experiences, saale, acquisition, delusion, flamboyant, empowering,
# Nearest to pressure: bhutto, breakdown, unscathed, anscombe, surge, outlets, dore, harun,
# Nearest to pre: unearth, cundinamarca, schmitt, ministerio, zooming, anticipation, wanted, cycladic,
# Nearest to mainly: attempts, especially, ancestry, telluride, in, principally, starchy, icelanders,
# Nearest to police: patrol, champ, government, diffuse, spirited, hurtful, ubs, tefan,
# Nearest to mathematics: arcturus, journeying, fermat, arithmetica, prodigies, cole, dtft, anthemius,
# Nearest to bbc: programmes, pbs, broadcasts, aerosol, biology, listing, belarussian, lycos,
# Nearest to discovered: discovery, discoveries, bombarding, hangovers, confirmed, paracelsus, stoll, valuable,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8674 0.0241 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8495 0.0235 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9247 0.0233 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8874 0.0232 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8948 0.0234 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8102 0.0230 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7633 0.0234 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8637 0.0233 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7589 0.0232 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8492 0.0232 sec/batch
# Nearest to these: some, many, been, such, are, of, even, most,
# Nearest to time: before, the, was, lived, at, shuja, early, a,
# Nearest to other: well, include, are, with, of, and, such, is,
# Nearest to was: became, when, in, the, but, he, were, been,
# Nearest to american: zal, islander, veterans, filipino, spingarn, nimo, jw, americans,
# Nearest to into: to, the, and, which, another, of, as, from,
# Nearest to are: there, or, is, in, some, other, example, such,
# Nearest to have: been, or, and, also, that, are, other, than,
# Nearest to experience: wellesley, strategist, experiences, saale, flamboyant, acquisition, mistakenly, kde,
# Nearest to pressure: bhutto, breakdown, surge, unscathed, outlets, anscombe, dore, harun,
# Nearest to pre: unearth, schmitt, zooming, cundinamarca, ministerio, wanted, anticipation, cycladic,
# Nearest to mainly: attempts, especially, principally, telluride, starchy, ancestry, arranged, malthusian,
# Nearest to police: patrol, government, champ, spirited, diffuse, jaeger, hurtful, criminal,
# Nearest to mathematics: arcturus, journeying, prodigies, arithmetica, fermat, cole, anthemius, university,
# Nearest to bbc: programmes, pbs, broadcasts, listing, aerosol, belarussian, day, biology,
# Nearest to discovered: discovery, bombarding, discoveries, hangovers, valuable, confirmed, sequenced, paracelsus,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8180 0.0243 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8297 0.0232 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
# show final result
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))    
    sim = similarity.eval()
    for i in range(valid_size):
        valid_word = int_to_vocab[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
            close_word = int_to_vocab[nearest[k]]
            log = '%s %s,' % (log, close_word)
        print(log)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt
# Nearest to these: some, many, been, of, such, most, are, even,
# Nearest to time: before, was, the, at, lived, shuja, when, celebrity,
# Nearest to other: well, include, with, such, of, are, and, similar,
# Nearest to was: became, when, but, the, in, he, were, been,
# Nearest to american: zal, islander, veterans, filipino, jw, navigator, americans, nimo,
# Nearest to into: to, the, and, which, of, another, with, as,
# Nearest to are: or, there, in, some, is, example, similar, other,
# Nearest to have: been, or, and, also, that, some, are, than,
# Nearest to experience: wellesley, strategist, experiences, saale, acquisition, flamboyant, spiritual, mistakenly,
# Nearest to pressure: bhutto, breakdown, surge, unscathed, outlets, anscombe, anemometers, harun,
# Nearest to pre: unearth, schmitt, cundinamarca, zooming, ministerio, wanted, anticipation, violating,
# Nearest to mainly: attempts, especially, principally, telluride, starchy, arranged, malthusian, gimme,
# Nearest to police: patrol, champ, government, spirited, diffuse, hurtful, jaeger, criminal,
# Nearest to mathematics: arcturus, journeying, arithmetica, prodigies, fermat, cole, anthemius, university,
# Nearest to bbc: programmes, pbs, broadcasts, listing, aerosol, day, belarussian, biology,
# Nearest to discovered: discovery, discoveries, bombarding, hangovers, valuable, confirmed, sequenced, stoll,

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 2000
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %%
# MORE INTERESTING WAYS TO VISUALIZE AT SUMMER SCHOOL FILES
