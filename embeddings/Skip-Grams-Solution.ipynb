# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /home/paperspace/anaconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/paperspace/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6696 0.0270 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6559 0.0231 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4962 0.0228 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5930 0.0229 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5218 0.0229 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5348 0.0228 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5564 0.0227 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4902 0.0231 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4579 0.0228 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3925 0.0228 sec/batch
# Nearest to some: zy, proportional, negara, has, audible, ivy, qarase, silo,
# Nearest to only: personification, transactions, algeciras, acta, bail, signs, noticed, hessen,
# Nearest to zero: language, participatory, musaf, pitman, offensive, abdallah, buddha, mischievous,
# Nearest to seven: served, epistemology, rocks, ectopic, parapet, nucleons, soichiro, malvinas,
# Nearest to up: pragmatist, rancher, rot, stabilizer, bodies, kong, drugged, barrows,
# Nearest to people: complemented, vaults, kli, legalized, passer, corresponding, hussites, talbot,
# Nearest to and: snedden, headlining, geosynchronous, breach, retractable, komondor, integration, greasy,
# Nearest to states: kilowatt, stave, bradykinin, popularising, secretions, moab, inconveniences, imagesize,
# Nearest to rise: also, unless, plaintexts, election, recast, solidifying, stauffenberg, axe,
# Nearest to animals: logotype, pursues, metta, khtml, lotharingia, hey, lzw, marino,
# Nearest to writers: debra, formant, multiplicity, alien, alimentarius, woodstock, curls, turner,
# Nearest to san: havre, trapezoidal, sentence, plasmid, major, stringed, sparse, wittelsbach,
# Nearest to magazine: safely, fact, hari, sociopath, competing, sabian, messe, scummvm,
# Nearest to shows: civilizing, casein, ishi, puritanical, commenting, demons, reintroducing, lycopene,
# Nearest to freedom: corey, junit, environmentalist, forever, element, roebuck, seasons, supernaturally,
# Nearest to egypt: scholarly, batsford, proportional, insufficient, prioritization, chevy, augustine, clarity,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4646 0.0237 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3828 0.0228 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3343 0.0227 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2502 0.0225 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1960 0.0231 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1652 0.0228 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0859 0.0229 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0541 0.0227 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9882 0.0227 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9754 0.0229 sec/batch
# Nearest to some: proportional, has, zy, larger, practically, own, ivy, theoretical,
# Nearest to only: transactions, personification, signs, noticed, bail, termed, hessen, well,
# Nearest to zero: language, participatory, offensive, reached, itv, televisions, concentrations, pitman,
# Nearest to seven: served, epistemology, rocks, diameter, nine, ectopic, j, an,
# Nearest to up: pragmatist, bodies, rancher, kong, developments, securing, drugged, hold,
# Nearest to people: corresponding, complemented, vaults, legalized, scales, are, felt, kli,
# Nearest to and: snedden, breach, integration, were, gilbert, geosynchronous, headlining, failing,
# Nearest to states: second, kilowatt, stave, artistic, popularising, disables, moab, published,
# Nearest to rise: also, unless, election, plaintexts, bring, recast, siege, canteen,
# Nearest to animals: logotype, pursues, sounds, grow, hey, marino, khtml, god,
# Nearest to writers: alien, multiplicity, law, researchers, express, eg, accurately, arboretum,
# Nearest to san: havre, sentence, major, offering, oshkosh, wittelsbach, stringed, trapezoidal,
# Nearest to magazine: fact, safely, competing, freedom, stony, role, quizzes, ch,
# Nearest to shows: ishi, demons, midlands, puritanical, lycopene, linked, civilizing, instance,
# Nearest to freedom: corey, forever, element, magazine, tool, seasons, open, computational,
# Nearest to egypt: proportional, scholarly, insufficient, batsford, importance, prioritization, augustine, clarity,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9198 0.0236 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9088 0.0227 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8632 0.0228 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8763 0.0228 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7923 0.0227 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7928 0.0231 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7900 0.0228 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7934 0.0229 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7618 0.0229 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7537 0.0229 sec/batch
# Nearest to some: zy, proportional, has, audible, practically, gilbert, ivy, larger,
# Nearest to only: transactions, personification, bail, signs, noticed, acta, algeciras, termed,
# Nearest to zero: participatory, language, televisions, itv, breakup, shaded, pitman, musaf,
# Nearest to seven: served, nine, six, epistemology, thomas, diameter, humanist, j,
# Nearest to up: pragmatist, bodies, rancher, kong, rot, implication, developments, drugged,
# Nearest to people: complemented, corresponding, vaults, brethren, legalized, hussites, passer, scales,
# Nearest to and: snedden, geosynchronous, failing, integration, headlining, breach, reorganizing, epidemic,
# Nearest to states: kilowatt, popularising, broadly, moab, magyars, disables, second, delays,
# Nearest to rise: also, unless, plaintexts, recast, solidifying, election, odos, bring,
# Nearest to animals: pursues, logotype, hey, grow, khtml, metta, sounds, lincoln,
# Nearest to writers: alien, multiplicity, turner, law, researchers, express, arboretum, eg,
# Nearest to san: havre, major, offering, wittelsbach, oshkosh, sentence, hb, sparse,
# Nearest to magazine: safely, fact, competing, messe, hari, freedom, drown, quizzes,
# Nearest to shows: ishi, demons, commenting, puritanical, cash, lycopene, convincingly, midlands,
# Nearest to freedom: corey, environmentalist, tool, forever, brown, element, supernaturally, roebuck,
# Nearest to egypt: scholarly, proportional, insufficient, augustine, clarity, prioritization, importance, bovines,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7576 0.0238 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7522 0.0228 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7257 0.0230 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6849 0.0227 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7099 0.0230 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7244 0.0229 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7122 0.0225 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7221 0.0229 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7038 0.0228 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6744 0.0228 sec/batch
# Nearest to some: zy, audible, pretentious, silo, has, proportional, practically, lr,
# Nearest to only: personification, transactions, bail, noticed, algeciras, termed, acta, hessen,
# Nearest to zero: participatory, televisions, breakup, shaded, timber, musaf, itv, falkland,
# Nearest to seven: nine, six, served, one, thomas, statesman, june, four,
# Nearest to up: pragmatist, rancher, bodies, implication, rot, kong, stabilizer, drugged,
# Nearest to people: complemented, brethren, hussites, vaults, corresponding, legalized, passer, liberal,
# Nearest to and: jakarta, integration, headlining, geosynchronous, breach, failing, snedden, epidemic,
# Nearest to states: kilowatt, moab, disables, magyars, broadly, subpoenaed, outings, westenra,
# Nearest to rise: also, unless, recast, plaintexts, solidifying, odos, combinatorics, pancreas,
# Nearest to animals: pursues, logotype, metta, khtml, grow, lotharingia, almighty, sounds,
# Nearest to writers: turner, alien, multiplicity, formant, woodstock, kenneth, mysteries, law,
# Nearest to san: havre, wittelsbach, hb, oshkosh, major, offering, city, devastation,
# Nearest to magazine: competing, hari, fact, messe, liz, safely, drown, petar,
# Nearest to shows: ishi, commenting, demons, civilizing, puritanical, midlands, convincingly, predicament,
# Nearest to freedom: corey, charisma, environmentalist, supernaturally, junit, roebuck, dislodge, tool,
# Nearest to egypt: scholarly, augustine, batsford, prioritization, clarity, insufficient, bovines, proportional,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6778 0.0237 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6684 0.0228 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6202 0.0228 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6325 0.0230 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6227 0.0228 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6349 0.0228 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5899 0.0176 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5616 0.0228 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5190 0.0230 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5126 0.0229 sec/batch
# Nearest to some: zy, audible, proportional, pretentious, silo, lr, has, practically,
# Nearest to only: personification, transactions, bail, noticed, algeciras, hessen, puranas, termed,
# Nearest to zero: participatory, televisions, musaf, itv, timber, falkland, shaded, breakup,
# Nearest to seven: nine, six, one, statesman, served, thomas, eight, four,
# Nearest to up: pragmatist, rancher, rot, bodies, implication, stabilizer, kong, polytechnic,
# Nearest to people: hussites, brethren, complemented, vaults, liberal, meath, passer, legalized,
# Nearest to and: geosynchronous, breach, headlining, jakarta, integration, combatted, snedden, failing,
# Nearest to states: moab, kilowatt, disables, westenra, subpoenaed, magyars, transshipment, receding,
# Nearest to rise: also, unless, plaintexts, recast, solidifying, combinatorics, bring, pancreas,
# Nearest to animals: pursues, metta, khtml, grow, logotype, crumpled, almighty, identical,
# Nearest to writers: turner, alien, multiplicity, mysteries, woodstock, formant, kenneth, debra,
# Nearest to san: havre, wittelsbach, city, oshkosh, hb, offering, major, bombay,
# Nearest to magazine: hari, competing, messe, liz, fact, drown, scummvm, effigy,
# Nearest to shows: civilizing, commenting, puritanical, ishi, demons, convincingly, casein, mage,
# Nearest to freedom: corey, charisma, environmentalist, supernaturally, junit, computational, tool, roebuck,
# Nearest to egypt: batsford, scholarly, augustine, prioritization, bovines, clarity, battles, bouvines,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4969 0.0238 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5084 0.0229 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4458 0.0233 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5085 0.0229 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4847 0.0226 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4875 0.0229 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4636 0.0226 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3791 0.0226 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4147 0.0227 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4146 0.0226 sec/batch
# Nearest to some: zy, audible, has, silo, proportional, lr, pretentious, practically,
# Nearest to only: personification, transactions, algeciras, bail, puranas, hessen, ludovic, cathal,
# Nearest to zero: timber, musaf, participatory, falkland, televisions, itv, population, seven,
# Nearest to seven: nine, six, one, served, olympic, eight, four, vander,
# Nearest to up: pragmatist, rancher, rot, bodies, implication, stabilizer, ammunition, offered,
# Nearest to people: brethren, hussites, complemented, vaults, liberal, meath, octavia, passer,
# Nearest to and: integration, geosynchronous, breathable, snedden, jakarta, breach, topography, reclaimed,
# Nearest to states: moab, kilowatt, westenra, disables, broadly, transshipment, keeling, kingdom,
# Nearest to rise: also, recast, unless, plaintexts, solidifying, combinatorics, odos, pancreas,
# Nearest to animals: pursues, metta, grow, khtml, there, logotype, crumpled, almighty,
# Nearest to writers: turner, alien, formant, woodstock, multiplicity, debra, mysteries, kenneth,
# Nearest to san: wittelsbach, havre, city, francais, oshkosh, hb, major, hornets,
# Nearest to magazine: competing, hari, liz, drown, messe, eve, sociopath, quizzes,
# Nearest to shows: civilizing, casein, puritanical, commenting, convincingly, mage, demons, wgn,
# Nearest to freedom: corey, charisma, tool, supernaturally, junit, dislodge, environmentalist, roebuck,
# Nearest to egypt: scholarly, batsford, augustine, prioritization, battles, bouvines, hawaiian, importance,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4610 0.0236 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4535 0.0226 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4571 0.0229 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4133 0.0230 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4240 0.0230 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4559 0.0233 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4168 0.0232 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3842 0.0230 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4173 0.0229 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3640 0.0230 sec/batch
# Nearest to some: zy, audible, pretentious, proportional, has, lr, silo, anticlockwise,
# Nearest to only: personification, bail, algeciras, transactions, puranas, acta, ludovic, tireless,
# Nearest to zero: one, musaf, seven, televisions, two, participatory, six, timber,
# Nearest to seven: nine, six, one, served, four, eight, vander, zero,
# Nearest to up: pragmatist, rot, rancher, implication, bodies, unforgiving, ammunition, stabilizer,
# Nearest to people: hussites, brethren, complemented, vaults, liberal, corrupt, octavia, meath,
# Nearest to and: integration, geosynchronous, crewman, inflationary, jakarta, headlining, tirpitz, evasion,
# Nearest to states: moab, kilowatt, subpoenaed, westenra, vietnam, broadly, transshipment, outings,
# Nearest to rise: also, recast, plaintexts, unless, odos, bring, pancreas, solidifying,
# Nearest to animals: pursues, metta, grow, there, khtml, crumpled, logotype, distinct,
# Nearest to writers: turner, alien, formant, kenneth, mysteries, woodstock, debra, davies,
# Nearest to san: wittelsbach, havre, oshkosh, city, francais, hb, hornets, burgundians,
# Nearest to magazine: liz, competing, hari, quizzes, drown, sociopath, effigy, eve,
# Nearest to shows: civilizing, puritanical, casein, mage, internationalized, wgn, yosemite, convincingly,
# Nearest to freedom: corey, charisma, tool, dislodge, environmentalist, competing, junit, supernaturally,
# Nearest to egypt: augustine, battles, batsford, prioritization, scholarly, bouvines, importance, goers,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3821 0.0240 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4080 0.0232 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3642 0.0230 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3559 0.0231 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3717 0.0230 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3599 0.0231 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3889 0.0232 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3757 0.0227 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3302 0.0230 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3599 0.0230 sec/batch
# Nearest to some: zy, has, pretentious, audible, practically, anticlockwise, proportional, lr,
# Nearest to only: personification, bail, algeciras, puranas, transactions, ludovic, cathal, tireless,
# Nearest to zero: one, seven, two, musaf, six, eight, est, participatory,
# Nearest to seven: six, one, nine, eight, four, five, zero, vander,
# Nearest to up: pragmatist, rancher, rot, bodies, unforgiving, karajan, ammunition, kkk,
# Nearest to people: hussites, brethren, complemented, seeking, vaults, liberal, meath, dependability,
# Nearest to and: inflationary, breathable, phosphoric, integration, jakarta, crewman, vom, reorganizing,
# Nearest to states: transshipment, moab, kilowatt, vietnam, westenra, broadly, subpoenaed, united,
# Nearest to rise: also, plaintexts, recast, pancreas, solidifying, odos, avesta, unless,
# Nearest to animals: metta, pursues, grow, khtml, crumpled, there, hide, teeth,
# Nearest to writers: turner, alien, formant, kenneth, debra, mysteries, woodstock, davies,
# Nearest to san: havre, wittelsbach, oshkosh, francais, city, bombay, hornets, hb,
# Nearest to magazine: liz, hari, quizzes, competing, uist, drown, sociopath, effigy,
# Nearest to shows: mage, puritanical, internationalized, casein, commenting, civilizing, wgn, demons,
# Nearest to freedom: charisma, corey, tool, environmentalist, dislodge, competing, theodorus, junit,
# Nearest to egypt: augustine, battles, batsford, prioritization, hawaiian, bouvines, scholarly, importance,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3809 0.0240 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2997 0.0234 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3977 0.0228 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3853 0.0231 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3770 0.0229 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2767 0.0230 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3253 0.0228 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3246 0.0226 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2088 0.0227 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2923 0.0230 sec/batch
# Nearest to some: zy, has, silo, audible, pretentious, instincts, practically, lr,
# Nearest to only: bail, personification, algeciras, transactions, puranas, tireless, cathal, ludovic,
# Nearest to zero: two, one, seven, six, four, eight, musaf, rate,
# Nearest to seven: nine, one, six, eight, four, five, zero, statesman,
# Nearest to up: pragmatist, rancher, rot, karajan, kkk, ammunition, unforgiving, eye,
# Nearest to people: hussites, brethren, complemented, seeking, meath, liberal, vaults, dependability,
# Nearest to and: dividends, inflationary, reorganizing, jakarta, albanian, integration, crewman, breathable,
# Nearest to states: transshipment, moab, vietnam, subpoenaed, westenra, united, kilowatt, legislature,
# Nearest to rise: also, recast, pancreas, plaintexts, solidifying, odos, avesta, bring,
# Nearest to animals: metta, pursues, grow, crumpled, hide, teeth, khtml, there,
# Nearest to writers: turner, kenneth, debra, formant, alien, woodstock, mysteries, taliesin,
# Nearest to san: havre, oshkosh, francais, wittelsbach, city, hornets, bombay, vikings,
# Nearest to magazine: liz, competing, hari, quizzes, uist, effigy, sociopath, sabian,
# Nearest to shows: mage, commenting, casein, yosemite, wgn, puritanical, internationalized, civilizing,
# Nearest to freedom: charisma, tool, corey, dislodge, environmentalist, junit, competing, theodorus,
# Nearest to egypt: augustine, battles, bouvines, batsford, dynasties, islamic, hawaiian, importance,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3127 0.0240 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3088 0.0230 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3363 0.0115 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2271 0.0229 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2307 0.0229 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2129 0.0230 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2230 0.0228 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2170 0.0232 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2224 0.0228 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2020 0.0230 sec/batch
# Nearest to some: zy, has, silo, practically, audible, instincts, rages, pretentious,
# Nearest to only: bail, personification, algeciras, tireless, transactions, puranas, cathal, ludovic,
# Nearest to zero: one, two, seven, four, musaf, six, televisions, eight,
# Nearest to seven: one, six, nine, eight, four, zero, five, vander,
# Nearest to up: pragmatist, ammunition, rot, rancher, karajan, unforgiving, kkk, eye,
# Nearest to people: hussites, brethren, seeking, complemented, meath, vaults, disagreeing, dependability,
# Nearest to and: phosphoric, crewman, underwater, dividends, breathable, cfb, inflationary, geosynchronous,
# Nearest to states: transshipment, westenra, vietnam, united, subpoenaed, kilowatt, moab, verde,
# Nearest to rise: also, recast, plaintexts, pancreas, solidifying, combinatorics, odos, avesta,
# Nearest to animals: metta, pursues, grow, crumpled, teeth, hide, strains, khtml,
# Nearest to writers: turner, debra, formant, kenneth, mysteries, taliesin, alien, woodstock,
# Nearest to san: havre, francais, oshkosh, wittelsbach, hornets, city, bombay, vikings,
# Nearest to magazine: liz, competing, quizzes, uist, hari, sociopath, effigy, sabian,
# Nearest to shows: mage, commenting, casein, internationalized, puritanical, civilizing, wgn, yosemite,
# Nearest to freedom: charisma, tool, environmentalist, corey, theodorus, ipt, junit, dislodge,
# Nearest to egypt: dynasties, augustine, battles, bouvines, mesopotamia, batsford, islamic, hawaiian,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2330 0.0238 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1994 0.0229 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2163 0.0229 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1169 0.0231 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1863 0.0230 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1886 0.0228 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1488 0.0230 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1701 0.0229 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2093 0.0227 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1843 0.0231 sec/batch
# Nearest to some: has, zy, silo, audible, anticlockwise, pretentious, practically, courting,
# Nearest to only: personification, bail, tireless, algeciras, puranas, cathal, ludovic, hoagie,
# Nearest to zero: one, two, four, seven, three, six, musaf, eight,
# Nearest to seven: one, six, nine, four, eight, zero, five, vander,
# Nearest to up: pragmatist, rot, ammunition, rancher, karajan, unforgiving, kkk, eye,
# Nearest to people: hussites, complemented, brethren, seeking, dovich, meath, disagreeing, vaults,
# Nearest to and: phosphoric, underwater, crewman, dividends, geosynchronous, cfb, tirpitz, inflationary,
# Nearest to states: subpoenaed, transshipment, kilowatt, verde, united, broadly, vietnam, lxiii,
# Nearest to rise: also, recast, pancreas, plaintexts, combinatorics, solidifying, odos, avesta,
# Nearest to animals: metta, pursues, grow, teeth, crumpled, hide, strains, khtml,
# Nearest to writers: debra, turner, kenneth, formant, mysteries, alien, taliesin, woodstock,
# Nearest to san: havre, francais, oshkosh, city, hornets, las, bombay, wittelsbach,
# Nearest to magazine: liz, competing, quizzes, hari, uist, effigy, sociopath, sabian,
# Nearest to shows: internationalized, casein, mage, wgn, commenting, demons, renting, yosemite,
# Nearest to freedom: tool, charisma, environmentalist, theodorus, corey, dislodge, ipt, palmerston,
# Nearest to egypt: augustine, battles, islamic, bouvines, dynasties, batsford, mesopotamia, relinquishing,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1970 0.0239 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1884 0.0232 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1891 0.0231 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1721 0.0230 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1909 0.0233 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1788 0.0228 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1990 0.0233 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1757 0.0231 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1488 0.0230 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1753 0.0229 sec/batch
# Nearest to some: zy, has, silo, anticlockwise, pretentious, audible, rages, instincts,
# Nearest to only: personification, tireless, bail, algeciras, transactions, adiabatic, incremented, puranas,
# Nearest to zero: two, one, seven, four, three, six, rate, eight,
# Nearest to seven: one, nine, six, eight, four, five, zero, vander,
# Nearest to up: pragmatist, rot, ammunition, kkk, rancher, karajan, unforgiving, eye,
# Nearest to people: hussites, complemented, seeking, brethren, dovich, disagreeing, orissa, dependability,
# Nearest to and: phosphoric, crewman, tirpitz, cfb, underwater, regio, integration, zoning,
# Nearest to states: subpoenaed, united, verde, kilowatt, transshipment, state, lxiii, kingdom,
# Nearest to rise: also, pancreas, recast, plaintexts, combinatorics, avesta, solidifying, odos,
# Nearest to animals: metta, pursues, teeth, grow, crumpled, strains, hide, plants,
# Nearest to writers: debra, turner, kenneth, taliesin, formant, woodstock, mysteries, collett,
# Nearest to san: havre, francais, oshkosh, hornets, las, bombay, dallas, wittelsbach,
# Nearest to magazine: liz, quizzes, competing, hari, uist, effigy, sociopath, sabian,
# Nearest to shows: internationalized, wgn, casein, mage, renting, anticolor, commenting, demons,
# Nearest to freedom: tool, charisma, environmentalist, theodorus, corey, rumsfeld, unenforceable, competing,
# Nearest to egypt: islamic, battles, expeditions, bouvines, augustine, dynasties, relinquishing, mesopotamia,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2072 0.0239 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1979 0.0234 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1688 0.0231 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1979 0.0230 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1758 0.0232 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1298 0.0232 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1796 0.0234 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1119 0.0231 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2079 0.0233 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1806 0.0229 sec/batch
# Nearest to some: zy, has, silo, pretentious, anticlockwise, rages, instincts, devoting,
# Nearest to only: bail, algeciras, tireless, personification, ludovic, formulario, hoagie, ayy,
# Nearest to zero: two, one, four, seven, eight, three, six, five,
# Nearest to seven: one, six, eight, nine, four, five, zero, statesman,
# Nearest to up: pragmatist, rot, rancher, kkk, quarterbacks, karajan, unforgiving, absconded,
# Nearest to people: hussites, brethren, seeking, disagreeing, complemented, dovich, ousterhout, orissa,
# Nearest to and: tirpitz, tatars, taschen, elias, ann, one, albanian, phosphoric,
# Nearest to states: subpoenaed, united, verde, state, kilowatt, vietnam, lxiii, kingdom,
# Nearest to rise: also, pancreas, recast, plaintexts, avesta, odos, bring, combinatorics,
# Nearest to animals: metta, teeth, pursues, crumpled, grow, strains, hide, insects,
# Nearest to writers: debra, kenneth, novelists, turner, taliesin, formant, woodstock, collett,
# Nearest to san: havre, francais, hornets, bombay, oshkosh, las, goebel, instant,
# Nearest to magazine: liz, quizzes, competing, uist, hari, sociopath, effigy, freedom,
# Nearest to shows: wgn, internationalized, yosemite, casein, demons, renting, mage, commenting,
# Nearest to freedom: tool, charisma, environmentalist, corey, theodorus, whitehead, unenforceable, rumsfeld,
# Nearest to egypt: islamic, expeditions, mesopotamia, bouvines, augustine, battles, dynasties, relinquishing,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2268 0.0240 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1332 0.0234 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1719 0.0231 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1333 0.0236 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0293 0.0241 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1641 0.0238 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1438 0.0238 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1228 0.0236 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1759 0.0056 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1288 0.0233 sec/batch
# Nearest to some: silo, has, zy, anticlockwise, instincts, rages, pretentious, courting,
# Nearest to only: tireless, bail, algeciras, adiabatic, formulario, hoagie, ayy, well,
# Nearest to zero: two, one, four, seven, three, eight, six, five,
# Nearest to seven: one, eight, six, nine, four, five, zero, three,
# Nearest to up: pragmatist, rot, karajan, rancher, ammunition, absconded, kkk, quarterbacks,
# Nearest to people: disagreeing, hussites, complemented, seeking, dovich, brethren, ousterhout, children,
# Nearest to and: phosphoric, underwater, crewman, depleting, deepen, tatars, form, zoning,
# Nearest to states: subpoenaed, verde, united, kilowatt, transshipment, state, lxiii, keeling,
# Nearest to rise: also, pancreas, recast, plaintexts, combinatorics, bring, barter, avesta,
# Nearest to animals: metta, pursues, teeth, crumpled, grow, strains, wild, hide,
# Nearest to writers: novelists, debra, kenneth, taliesin, turner, formant, have, woodstock,
# Nearest to san: havre, hornets, francais, oshkosh, las, bombay, dallas, goebel,
# Nearest to magazine: liz, sociopath, uist, hari, competing, quizzes, plankalk, messe,
# Nearest to shows: wgn, internationalized, commenting, yosemite, demons, renting, mage, scapegoats,
# Nearest to freedom: tool, charisma, environmentalist, corey, theodorus, unenforceable, dislodge, whitehead,
# Nearest to egypt: islamic, mesopotamia, augustine, expeditions, bouvines, hellenistic, dynasties, befriends,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0857 0.0242 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0863 0.0234 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1054 0.0234 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0518 0.0231 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0834 0.0231 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0442 0.0230 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0853 0.0229 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0879 0.0231 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1193 0.0230 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0410 0.0230 sec/batch
# Nearest to some: silo, has, zy, anticlockwise, pretentious, rages, instincts, courting,
# Nearest to only: tireless, well, bail, algeciras, formulario, personification, monothelitism, embolism,
# Nearest to zero: two, one, three, four, seven, eight, five, six,
# Nearest to seven: one, six, eight, nine, four, five, zero, vander,
# Nearest to up: pragmatist, ammunition, rot, rancher, karajan, quarterbacks, derail, conquer,
# Nearest to people: hussites, disagreeing, complemented, seeking, ousterhout, children, deaths, orissa,
# Nearest to and: underwater, phosphoric, zoning, were, tatars, cfb, depleting, their,
# Nearest to states: united, subpoenaed, verde, kilowatt, transshipment, vietnam, state, keeling,
# Nearest to rise: also, pancreas, recast, plaintexts, combinatorics, buff, rising, bring,
# Nearest to animals: metta, pursues, teeth, crumpled, strains, grow, wild, hide,
# Nearest to writers: novelists, debra, taliesin, kenneth, formant, turner, collett, have,
# Nearest to san: havre, hornets, francais, las, dallas, oshkosh, bombay, goebel,
# Nearest to magazine: liz, uist, sociopath, hari, messe, plankalk, effigy, competing,
# Nearest to shows: wgn, commenting, yosemite, internationalized, renting, stefani, hj, casein,
# Nearest to freedom: tool, charisma, environmentalist, theodorus, junit, whitehead, unenforceable, corey,
# Nearest to egypt: islamic, mesopotamia, augustine, hellenistic, expeditions, bouvines, dynasties, befriends,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0348 0.0241 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0514 0.0231 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0163 0.0230 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0570 0.0230 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0631 0.0232 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0528 0.0232 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0666 0.0232 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0911 0.0229 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0410 0.0227 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0764 0.0224 sec/batch
# Nearest to some: silo, has, zy, instincts, anticlockwise, pretentious, courting, audible,
# Nearest to only: tireless, well, adiabatic, personification, formulario, transactions, zodiacal, bail,
# Nearest to zero: one, two, four, three, seven, five, six, eight,
# Nearest to seven: one, six, nine, eight, five, four, zero, three,
# Nearest to up: pragmatist, rot, rancher, quarterbacks, kkk, karajan, ammunition, conquer,
# Nearest to people: children, dovich, disagreeing, deaths, hussites, complemented, seeking, orissa,
# Nearest to and: phosphoric, form, underwater, chemistry, zoning, together, crewman, tirpitz,
# Nearest to states: united, subpoenaed, verde, baryonic, kilowatt, state, lxiii, transshipment,
# Nearest to rise: also, pancreas, recast, combinatorics, plaintexts, buff, avesta, ardant,
# Nearest to animals: metta, pursues, teeth, crumpled, strains, mammals, aye, grow,
# Nearest to writers: novelists, debra, taliesin, kenneth, palgrave, turner, formant, have,
# Nearest to san: havre, las, hornets, francais, oshkosh, bombay, dallas, goebel,
# Nearest to magazine: liz, sociopath, uist, plankalk, hari, messe, quizzes, quality,
# Nearest to shows: wgn, internationalized, yosemite, renting, commenting, casein, anticolor, demons,
# Nearest to freedom: tool, charisma, environmentalist, theodorus, unenforceable, whitehead, junit, corey,
# Nearest to egypt: islamic, expeditions, augustine, hellenistic, bouvines, mesopotamia, pretenders, rabi,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0609 0.0235 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1021 0.0227 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0859 0.0226 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0578 0.0224 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0571 0.0225 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0744 0.0230 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0733 0.0227 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0359 0.0226 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1004 0.0226 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0567 0.0228 sec/batch
# Nearest to some: has, silo, instincts, rages, zy, anticlockwise, pretentious, bioko,
# Nearest to only: well, tireless, algeciras, personification, transactions, granary, bail, chores,
# Nearest to zero: two, one, four, seven, three, five, six, eight,
# Nearest to seven: one, six, eight, five, four, nine, zero, three,
# Nearest to up: pragmatist, rancher, rot, conquer, absconded, kkk, langevin, mavericks,
# Nearest to people: children, hussites, seeking, deaths, complemented, dovich, orissa, list,
# Nearest to and: phosphoric, tatars, form, were, taschen, consuls, tirpitz, opposed,
# Nearest to states: united, verde, subpoenaed, kilowatt, lxiii, state, vietnam, munster,
# Nearest to rise: also, pancreas, recast, ardant, buff, avesta, barter, plaintexts,
# Nearest to animals: metta, pursues, teeth, crumpled, strains, wild, mammals, aye,
# Nearest to writers: novelists, debra, have, kenneth, turner, taliesin, palgrave, satirists,
# Nearest to san: havre, las, hornets, francais, francisco, goebel, oshkosh, bombay,
# Nearest to magazine: liz, sociopath, uist, plankalk, messe, effigy, songbook, quality,
# Nearest to shows: wgn, hj, yosemite, internationalized, scapegoats, renting, commenting, called,
# Nearest to freedom: tool, charisma, environmentalist, theodorus, unenforceable, corey, whitehead, junit,
# Nearest to egypt: islamic, augustine, hellenistic, expeditions, pretenders, mesopotamia, bouvines, relinquishing,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0560 0.0236 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9911 0.0223 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0416 0.0224 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0815 0.0225 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0777 0.0230 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1077 0.0230 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1470 0.0227 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0422 0.0225 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0188 0.0223 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0724 0.0228 sec/batch
# Nearest to some: has, silo, instincts, zy, rages, anticlockwise, audible, courting,
# Nearest to only: well, tireless, personification, hoagie, bail, algeciras, chores, granary,
# Nearest to zero: two, one, four, three, five, seven, eight, six,
# Nearest to seven: one, six, eight, five, nine, four, zero, two,
# Nearest to up: pragmatist, rancher, conquer, absconded, quarterbacks, derail, kkk, rot,
# Nearest to people: deaths, dovich, children, hussites, complemented, list, seeking, disagreeing,
# Nearest to and: phosphoric, form, underwater, edgy, tatars, unrecognized, tirpitz, derive,
# Nearest to states: united, subpoenaed, verde, state, kilowatt, lxiii, warrant, kingdom,
# Nearest to rise: also, pancreas, recast, ardant, buff, rising, plaintexts, ideology,
# Nearest to animals: metta, pursues, crumpled, teeth, aye, strains, wild, mammals,
# Nearest to writers: novelists, debra, have, kenneth, palgrave, taliesin, satirists, turner,
# Nearest to san: havre, hornets, francais, francisco, las, goebel, oshkosh, bombay,
# Nearest to magazine: liz, sociopath, uist, plankalk, messe, effigy, songbook, hari,
# Nearest to shows: wgn, yosemite, hj, scapegoats, renting, rutles, internationalized, called,
# Nearest to freedom: tool, charisma, environmentalist, unenforceable, junit, palmerston, theodorus, whitehead,
# Nearest to egypt: islamic, augustine, hellenistic, expeditions, pretenders, relinquishing, mesopotamia, bouvines,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9707 0.0235 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0587 0.0226 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0563 0.0225 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0238 0.0227 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0852 0.0227 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0437 0.0219 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0173 0.0226 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9614 0.0226 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0306 0.0226 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9956 0.0225 sec/batch
# Nearest to some: has, silo, rages, instincts, zy, pretentious, courting, anticlockwise,
# Nearest to only: well, personification, pickups, tireless, formulario, transactions, adiabatic, puranas,
# Nearest to zero: two, one, four, three, five, seven, six, eight,
# Nearest to seven: one, six, eight, five, nine, four, zero, three,
# Nearest to up: pragmatist, conquer, tines, rot, derail, rancher, karajan, kkk,
# Nearest to people: children, deaths, dovich, disagreeing, complemented, hussites, seeking, alumni,
# Nearest to and: phosphoric, underwater, their, form, depleting, unrecognized, together, josephine,
# Nearest to states: united, subpoenaed, verde, kilowatt, baryonic, lxiii, state, munster,
# Nearest to rise: also, pancreas, recast, buff, rising, ardant, fall, combinatorics,
# Nearest to animals: metta, pursues, crumpled, aye, teeth, mammals, strains, wild,
# Nearest to writers: novelists, have, debra, satirists, palgrave, taliesin, kenneth, formant,
# Nearest to san: havre, hornets, las, francisco, francais, goebel, oshkosh, instant,
# Nearest to magazine: liz, sociopath, uist, plankalk, effigy, songbook, messe, sabian,
# Nearest to shows: hj, scapegoats, yosemite, wgn, internationalized, renting, similarities, casein,
# Nearest to freedom: tool, charisma, environmentalist, unenforceable, junit, palmerston, theodorus, deducted,
# Nearest to egypt: hellenistic, augustine, pretenders, mesopotamia, islamic, relinquishing, befriends, clarity,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0191 0.0236 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9449 0.0227 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0307 0.0225 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0146 0.0226 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0245 0.0227 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9969 0.0229 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9193 0.0223 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9497 0.0223 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9099 0.0223 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9960 0.0224 sec/batch
# Nearest to some: has, silo, anticlockwise, rages, zy, instincts, culture, courting,
# Nearest to only: well, personification, chores, pickups, tireless, granary, are, formulario,
# Nearest to zero: two, one, four, five, three, seven, six, eight,
# Nearest to seven: six, one, eight, five, zero, four, nine, two,
# Nearest to up: pragmatist, tines, conquer, rot, ammunition, karajan, flares, megabytes,
# Nearest to people: deaths, children, list, alumni, complemented, orissa, disagreeing, seeking,
# Nearest to and: phosphoric, one, form, underwater, together, their, chemistry, of,
# Nearest to states: united, subpoenaed, verde, kilowatt, state, baryonic, lxiii, subnational,
# Nearest to rise: also, pancreas, recast, buff, ardant, rising, fall, combinatorics,
# Nearest to animals: metta, pursues, aye, crumpled, teeth, mammals, strains, everton,
# Nearest to writers: novelists, debra, satirists, have, taliesin, palgrave, kenneth, collett,
# Nearest to san: havre, francisco, las, hornets, francais, goebel, diego, dallas,
# Nearest to magazine: liz, sociopath, uist, songbook, plankalk, effigy, messe, journalistic,
# Nearest to shows: hj, yosemite, wgn, scapegoats, renting, internationalized, stefani, casein,
# Nearest to freedom: tool, charisma, environmentalist, unenforceable, junit, conservationist, deducted, dislodge,
# Nearest to egypt: hellenistic, islamic, augustine, mesopotamia, pretenders, expeditions, relinquishing, sinthasomphone,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9884 0.0237 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9882 0.0229 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9802 0.0224 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9984 0.0227 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0310 0.0226 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9633 0.0228 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9902 0.0225 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9864 0.0227 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9848 0.0226 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9939 0.0226 sec/batch
# Nearest to some: has, silo, anticlockwise, instincts, zy, rages, larger, practically,
# Nearest to only: well, personification, pickups, formulario, are, adiabatic, puranas, granary,
# Nearest to zero: two, one, four, five, three, seven, six, eight,
# Nearest to seven: one, six, five, eight, nine, four, zero, two,
# Nearest to up: pragmatist, tines, conquer, rot, kkk, karajan, megabytes, quarterbacks,
# Nearest to people: deaths, children, list, alumni, dovich, orissa, complemented, disagreeing,
# Nearest to and: phosphoric, their, together, one, edgy, taschen, form, voegelin,
# Nearest to states: united, subpoenaed, verde, lxiii, baryonic, kilowatt, state, kingdom,
# Nearest to rise: pancreas, also, recast, ardant, buff, fall, rising, ideology,
# Nearest to animals: metta, pursues, aye, mammals, crumpled, teeth, strains, taxonomic,
# Nearest to writers: novelists, debra, have, satirists, kenneth, deaths, palgrave, poets,
# Nearest to san: francisco, havre, las, hornets, goebel, instant, francais, dallas,
# Nearest to magazine: liz, journalistic, sociopath, uist, plankalk, songbook, magazines, messe,
# Nearest to shows: hj, scapegoats, wgn, yosemite, internationalized, called, renting, rutles,
# Nearest to freedom: tool, charisma, environmentalist, conservationist, unenforceable, junit, whitehead, shtml,
# Nearest to egypt: islamic, pretenders, augustine, relinquishing, rabi, forma, hellenistic, sinthasomphone,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0030 0.0242 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9693 0.0230 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
